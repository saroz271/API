# %%
# libraries that will be used for this project
import json
import urllib3
import pandas as pd
from pandas import DataFrame
import datetime as dt
import numpy as np

# %%
# Create variables for the API key required for an API request
API_KEY ='ff47b280-5bf7-11ea-9b44-2df473addcc2'

# %%
# Use urllib to create a GET request to the API
# The request includes the API key variable that was created, 
# a request for 99 entries (maximum per API rules), and any containing the word "dog"
http = urllib3.PoolManager()

r = http.request('GET', 'https://api.harvardartmuseums.org/object',
    fields = {
        'apikey': API_KEY,
        'title': 'cat',
        'size': 99
    })

# display initial pull of data
print(r.data)
# Out:
# C:\Users\saroj\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# b'{"info":{"totalrecordsperquery":99,"totalrecords":318,"pages":4,"page":1,"next":"https://api.harvardartmuseums.org/object?apikey=ff47b280-5bf7-11ea-9b44-2df473addcc2&title=cat&size=99&page=2"},"records":[{"accessionyear":null,"technique":"Etching","mediacount":0,"edition":null,"totalpageviews":51,"groupcount":0,"people":[{"alphasort":"Bodmer, Karl (Johann Carl)","birthplace":"Zurich, Switzerland","name":"Karl Bodmer","prefix":null,"personid":28518,"gender":"male","role":"Artist","displayorder":1,"culture":"Swiss","displaydate":"1809 - 1893","deathplace":"Paris, France","displayname":"Karl Bodmer"}],"objectnumber":"R4991","colorcount":7,"lastupdate":"2020-02-28T05:56:34-0500","rank":247828,"imagecount":1,"description":null,"dateoflastpageview":"2019-04-29","dateoffirstpageview":"2011-06-14","primaryimageurl":"https://nrs.harvard.edu/urn-3:HUAM:INV176130_dynmc","colors":[{"percent":0.244,"spectrum":"#8e5ea7","color":"#afaf96","css3":"#a9a9a9","hue":"Green"},{"percent":0.20069841269841,"spectrum":"#6cbd45","color":"#7d7d64","css3":"#808080","hue":"Yellow"},{"percent":0.1968253968254,"spectrum":"#8e5ea7","color":"#96967d","css3":"#808080","hue":"Green"},{"percent":0.176,"spectrum":"#59ba4a","color":"#64644b","css3":"#696969","hue":"Green"},{"percent":0.094222222222222,"spectrum":"#4ab851","color":"#4b4b32","css3":"#556b2f","hue":"Green"},{"percent":0.044380952380952,"spectrum":"#b55592","color":"#c8afaf","css3":"#c0c0c0","hue":"Red"},{"percent":0.043873015873016,"spectrum":"#3db657","color":"#323219","css3":"#2f4f4f","hue":"Brown"}],"dated":"19th century","contextualtextcount":0,"copyright":null,"period":null,"accessionmethod":"Gift","url":"https://www.harvardartmuseums.org/collections/object/240212","provenance":"John Witt Randall, bequest to his sister.\\r\\nBelinda Lull Randall, gift to Harvard University, 1892. sister of John Witt Randall\\r\\n","images":[{"height":1024,"iiifbaseuri":"https://ids.lib.harvard.edu/ids/iiif/20433307","baseimageurl":"https://nrs.harvard.edu/urn-3:HUAM:INV176130_dynmc","width":721,"publiccaption":null,"idsid":20433307,"displayorder":1,"format":"image/jpeg","copyright":"President and Fellows of Harvard College","imageid":290356,"renditionnumber":"INV176130"}],"publicationcount":0,"objectid":240212,"culture":"French","verificationleveldescription":"Good. Object is well described and information is vetted","standardreferencenumber":"Ber. 26","worktypes":[{"worktypeid":"278","worktype":"print"}],"department":"Department of Prints","state":null,"markscount":0,"contact":"am_europeanamerican@harvard.edu","titlescount":3,"id":240212,"title":"Cat Playing with a Grass Snake","verificationlevel":3,"division":"European and American Art","style":null,"commentary":null,"relatedcount":0,"datebegin":0,"labeltext":null,"totaluniquepageviews":43,"dimensions":"plate: 15.7 x 11.8 cm (6 3/16 x 4 5/8 in.)","exhibitioncount":0,"techniqueid":116,"dateend":0,"creditline":"Harvard Art Museums/Fogg Museum, Gift of Belinda L. Randall from the collection of John Witt Randall","imagepermissionlevel":0,"signed":null,"periodid":null,"century":"19th century","classificationid":23,"medium":null,"peoplecount":1,"accesslevel":1,"classification":"Prints","seeAlso":[{"id":"https://iiif.harvardartmuseums.org/manifests/object/240212","type":"IIIF Manifest","format":"application/json","profile":"http://iiif.io/api/presentation/2/context.json"}]},{"accessionyear":null,"technique":"Engraving","mediacount":0,"edition":null,"totalpageviews":12,"groupcount":0,"people":[{"alphasort":"Burnet, John","birthplace":null,"name":"John Burnet","prefix":null,"personid":31445,"gender":"male","role":"Artist","displayorder":1,"culture":"British","displaydate":"1784 - 1868","deathplace":null,"displayname":"John Burnet"},{"alphasort":"Mieris, Frans van the Elder","birthplace":"Leiden, Netherlands","name":"Frans van Mieris the Elder","prefix":"After","personid":27589,"gender":"unknown","role":"Artist after","displayorder":2,"culture":"Dutch","displaydate":" ...

# %%
# convert into json format.  
data_u = json.loads(r.data)

# %%
# We need to use the information in the records list so verify that it did come through as a list
print(type(data_u["records"]))
# Out:
# <class 'list'>

# %%
# Verify that the variables can be called
for record in data_u["records"]:
    print(record['provenance'])
# Out:
# John Witt Randall, bequest to his sister.
# Belinda Lull Randall, gift to Harvard University, 1892. sister of John Witt Randall
#
# John Witt Randall, bequest to his sister.
# Belinda Lull Randall, gift to Harvard University, 1892. sister of John Witt Randall
#
# John Witt Randall, bequest to his sister.
# Belinda Lull Randall, sister of John Witt Randall, gift to Harvard University, 1892.
#
# None
# None
# None
# None
# None
# None
# None
# Connie Mangskan (?), Bangkok
# [Bridgewater/Lustberg & Blumenfeld Gallery, New York, New York], sold; to Harvard University Art Museums, July 27, 1999.
# [Bridgewater/Lustberg & Blumenfeld Gallery, New York, New York], sold; to Harvard University Art Museums, July 27, 1999.
# None
# None
# None
# None
# None
# None
#
# None
# None
# None
# Brought from Sardis; by Frederick Marquand Godwin, New York, (by 1914), by descent; to his wife Dorothy W. Godwin, New York (1914-1964), gift; to the Fogg Museum of Art, 1964.
#
# Note: Frederick M. Godwin was the photographer for the excavations at Sardis with Howard Crosby Butler in 1913 and 1914.
# Maida and George Abrams, Boston, gift; to Fogg Art Museum, 1982.
#
# None
# None
# None
# None
# John Witt Randall, Boston, MA;  bequest to his sister Belinda L. Randall, 1892; gift to Harvard University, 1892.
# [Heeramaneck Galleries, NY, by 1966], sold; to Mr. and Mrs. Peter Bienstock, NY, (1966-1974), gift; to The Fogg Museum of Art.
# Marian H. Phinney, Cambridge, MA, (by 1962), bequest; to Fogg Art Museum, 1962.
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Francis Calley Gray, bequest to nephew, 1856.
# William Gray, gift to Harvard University, 1857.
#
# None
# Folkwang Museum, Essen, by 1929, removed from the collection by the National Socialist (Nazi) authorities, 1937 (EK 3689), sold; [Galerie Ferdinand Möller, Berlin], sold; to Kurt Feldhäusser, Berlin,by inheritance; Marie Feldhäusser, Brooklyn (1945-c. 1949)  sold; [E. Weyhe Gallery, New York], sold; to Busch-Reisinger Museum, February 1950.
# Richard M. Burgess, Minneapolis, Minnesota, bequest; to Private Collector, gift; to Fogg Art Museum, 1960.
#
# NOTE: Provenance taken from correspondence in the curatorial file.
# None
# None
# None
# [Grisebach GmbH, November 25, 2004, lot 01180], sold; to Jeane von Oppenheim (2004-2017), gift; to the Busch-Reisinger Museum, 2017.
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Hermann Bünemann, Munich, Germany, gift; to Wolfgang and Emmerich Bünemann, Munich, Germany, gift; to the Busch-Reisinger Museum, 2011.
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
# Create a list that pulls only the needed variables for the project
all_data = []
for record in data_u["records"]:
    data_dict = {}
    data_dict['Title'] = record["title"]
    data_dict['Date_Begin'] = record["datebegin"]
    data_dict['Total_Page_Views'] = record["totalpageviews"]
    data_dict['Technique_ID'] = record["techniqueid"]
    data_dict['Provenance'] = record["provenance"]
    data_dict['Century'] = record["century"]
    data_dict['Object_ID'] = record["objectid"]
    data_dict['Accession_Method'] = record["accessionmethod"]
    data_dict['Period'] = record["period"]
    data_dict['Rank'] = record["rank"]
    data_dict['Edition'] = record["edition"]
    data_dict['Culture'] = record["culture"]
    data_dict['Signed'] = record["signed"]
    data_dict['Date_Of_Last_Page_View'] = record["dateoflastpageview"]
    data_dict['Style'] = record["style"]
    data_dict['Technique'] = record["technique"]
    data_dict['Date_End'] = record["dateend"]
    all_data.append(data_dict)

# %%
print(all_data)
# Verify that the list has been created
# Out:
# [{'Title': 'Cat Playing with a Grass Snake', 'Date_Begin': 0, 'Total_Page_Views': 51, 'Technique_ID': 116, 'Provenance': 'John Witt Randall, bequest to his sister.\r\nBelinda Lull Randall, gift to Harvard University, 1892. sister of John Witt Randall\r\n', 'Century': '19th century', 'Object_ID': 240212, 'Accession_Method': 'Gift', 'Period': None, 'Rank': 247828, 'Edition': None, 'Culture': 'French', 'Signed': None, 'Date_Of_Last_Page_View': '2019-04-29', 'Style': None, 'Technique': 'Etching', 'Date_End': 0}, {'Title': 'The Cat', 'Date_Begin': 0, 'Total_Page_Views': 12, 'Technique_ID': 98, 'Provenance': 'John Witt Randall, bequest to his sister.\r\nBelinda Lull Randall, gift to Harvard University, 1892. sister of John Witt Randall\r\n', 'Century': '19th century', 'Object_ID': 245755, 'Accession_Method': 'Gift', 'Period': None, 'Rank': 253391, 'Edition': None, 'Culture': 'British', 'Signed': None, 'Date_Of_Last_Page_View': '2019-04-08', 'Style': None, 'Technique': 'Engraving', 'Date_End': 0}, {'Title': 'Wild Cat', 'Date_Begin': 0, 'Total_Page_Views': 3, 'Technique_ID': 116, 'Provenance': 'John Witt Randall, bequest to his sister.\r\nBelinda Lull Randall, sister of John Witt Randall, gift to Harvard University, 1892.\r\n', 'Century': '17th-18th century', 'Object_ID': 247933, 'Accession_Method': 'Gift', 'Period': None, 'Rank': 248777, 'Edition': None, 'Culture': 'German', 'Signed': None, 'Date_Of_Last_Page_View': '2019-08-28', 'Style': None, 'Technique': 'Etching', 'Date_End': 0}, {'Title': 'White Cat and Red Flowers', 'Date_Begin': 0, 'Total_Page_Views': 111, 'Technique_ID': None, 'Provenance': None, 'Century': None, 'Object_ID': 202700, 'Accession_Method': 'Purchase', 'Period': 'Qing dynasty, 1644-1911', 'Rank': 90034, 'Edition': None, 'Culture': 'Chinese', 'Signed': None, 'Date_Of_Last_Page_View': '2020-02-26', 'Style': None, 'Technique': None, 'Date_End': 0}, {'Title': 'Sleeping Cat', 'Date_Begin': 0, 'Total_Page_Views': 9, 'Technique_ID': None, 'Provenance': None, 'Century': '20th century', 'Object_ID': 202986, 'Accession_Method': 'Bequest', 'Period': None, 'Rank': 85783, 'Edition': None, 'Culture': 'Japanese', 'Signed': 'signature (illegible) and two seals', 'Date_Of_Last_Page_View': '2016-02-22', 'Style': None, 'Technique': None, 'Date_End': 0}, {'Title': 'Cat and Goldfish Bowl', 'Date_Begin': 1765, 'Total_Page_Views': 84, 'Technique_ID': None, 'Provenance': None, 'Century': '18th century', 'Object_ID': 206355, 'Accession_Method': 'Gift', 'Period': 'Edo period, 1615-1868', 'Rank': 60095, 'Edition': None, 'Culture': 'Japanese', 'Signed': '(printed) Koryūsai ga', 'Date_Of_Last_Page_View': '2020-02-17', 'Style': None, 'Technique': None, 'Date_End': 1780}, {'Title': 'A Fox, a Cat, and a Boy Visiting The Inari Shrine', 'Date_Begin': 0, 'Total_Page_Views': 5, 'Technique_ID': None, 'Provenance': None, 'Century': None, 'Object_ID': 208140, 'Accession_Method': 'Gift', 'Period': 'Edo period, 1615-1868', 'Rank': 58762, 'Edition': None, 'Culture': 'Japanese', 'Signed': None, 'Date_Of_Last_Page_View': '2019-09-14', 'Style': None, 'Technique': None, 'Date_End': 0}, {'Title': 'Old Women with Two Cats', 'Date_Begin': 0, 'Total_Page_Views': 9, 'Technique_ID': 116, 'Provenance': None, 'Century': '17th century', 'Object_ID': 234058, 'Accession_Method': None, 'Period': None, 'Rank': 257129, 'Edition': None, 'Culture': 'French', 'Signed': None, 'Date_Of_Last_Page_View': '2019-04-08', 'Style': None, 'Technique': 'Etching', 'Date_End': 0}, {'Title': 'Cat and the Caged Bird', 'Date_Begin': 0, 'Total_Page_Views': 14, 'Technique_ID': 116, 'Provenance': None, 'Century': '17th century', 'Object_ID': 234410, 'Accession_Method': None, 'Period': None, 'Rank': 256803, 'Edition': None, 'Culture': 'French', 'Signed': None, 'Date_Of_Last_Page_View': '2013-10-13', 'Style': None, 'Technique': 'Etching', 'Date_End': 0}, {'Title': 'Cat', 'Date_Begin': 0, 'Total_Page_Views': 6, 'Technique_ID': None, 'Provenance': None, 'Century': '20th century', 'Object_ID': 2251 ...

# %%
# Convert data to a Pandas dataframe so it is in a readable and usable format
df = DataFrame(all_data)
df
# Out:
#                                                 Title  Date_Begin  \
# 0                      Cat Playing with a Grass Snake           0
# 1                                             The Cat           0
# 2                                            Wild Cat           0
# 3                           White Cat and Red Flowers           0
# 4                                        Sleeping Cat           0
# ..                                                ...         ...
# 94  Untitled (two cats in boxing ring wearing gloves)        1945
# 95  Untitled (two standing cats wearing gloves and...        1946
# 96  Untitled (man standing behind small boxing rin...        1946
# 97  Untitled (woman seated with cat on sofa in liv...        1935
# 98  Untitled (wedding guests watching a cat eat fr...        1953
#
#     Total_Page_Views  Technique_ID  \
# 0                 51         116.0
# 1                 12          98.0
# 2                  3         116.0
# 3                111           NaN
# 4                  9           NaN
# ..               ...           ...
# 94               218         107.0
# 95                30         107.0
# 96                20         107.0
# 97                 5         107.0
# 98                12         107.0
#
#                                            Provenance            Century  \
# 0   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 1   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 2   John Witt Randall, bequest to his sister.\r\nB...  17th-18th century
# 3                                                None               None
# 4                                                None       20th century
# ..                                                ...                ...
# 94                                               None       20th century
# 95                                               None       20th century
# 96                                               None       20th century
# 97                                               None       20th century
# 98                                               None       20th century
#
#     Object_ID Accession_Method                   Period    Rank Edition  \
# 0      240212             Gift                     None  247828    None
# 1      245755             Gift                     None  253391    None
# 2      247933             Gift                     None  248777    None
# 3      202700         Purchase  Qing dynasty, 1644-1911   90034    None
# 4      202986          Bequest                     None   85783    None
# ..        ...              ...                      ...     ...     ...
# 94     127739         Transfer                     None   33381    None
# 95     127747         Transfer                     None   33410    None
# 96     127748         Transfer                     None   33411    None
# 97     129758         Transfer                     None   31587    None
# 98     133408         Transfer                     None   27823    None
#
#      Culture                               Signed Date_Of_Last_Page_View  \
# 0     French                                 None             2019-04-29
# 1    British                                 None             2019-04-08
# 2     German                                 None             2019-08-28
# 3    Chinese                                 None             2020-02-26
# 4   Japanese  signature (illegible) and two seals             2016-02-22
# ..       ...                                  ...                    ...
# 94  American                                 None             2019-10-03
# 95  American                                 None             2019-07-09
# 96  American                                 None             2018-10-02
# 97  American                                 None             2017-10-29
# 98  American                                 None             2015-11-09
#
#    Style                        Technique  Date_End
# 0   None                          Etching         0
# 1   None                        Engraving         0
# 2   None                          Etching         0
# 3   None                             None         0
# 4   None                             None         0
# ..   ...                              ...       ...
# 94  None  Negative, gelatin silver (film)      1955
# 95  None  Negative, gelatin silver (film)      1946
# 96  None  Negative, gelatin silver (film)      1946
# 97  None  Negative, gelatin silver (film)      1945
# 98  None  Negative, gelatin silver (film)      1953
#
# [99 rows x 17 columns]

# %%
# DATA TRANSFORMATION # 1
# Reformat Date of Last Page View
# Convert column values to date format
df['Date_Of_Last_Page_View'] = pd.to_datetime(df.Date_Of_Last_Page_View)

# %%
# Create new column in dataframe with date in updated format
df['Date_Of_Last_Page_View_String'] = df['Date_Of_Last_Page_View'].dt.strftime('%m/%d/%Y')
df
# Out:
#                                                 Title  Date_Begin  \
# 0                      Cat Playing with a Grass Snake           0
# 1                                             The Cat           0
# 2                                            Wild Cat           0
# 3                           White Cat and Red Flowers           0
# 4                                        Sleeping Cat           0
# ..                                                ...         ...
# 94  Untitled (two cats in boxing ring wearing gloves)        1945
# 95  Untitled (two standing cats wearing gloves and...        1946
# 96  Untitled (man standing behind small boxing rin...        1946
# 97  Untitled (woman seated with cat on sofa in liv...        1935
# 98  Untitled (wedding guests watching a cat eat fr...        1953
#
#     Total_Page_Views  Technique_ID  \
# 0                 51         116.0
# 1                 12          98.0
# 2                  3         116.0
# 3                111           NaN
# 4                  9           NaN
# ..               ...           ...
# 94               218         107.0
# 95                30         107.0
# 96                20         107.0
# 97                 5         107.0
# 98                12         107.0
#
#                                            Provenance            Century  \
# 0   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 1   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 2   John Witt Randall, bequest to his sister.\r\nB...  17th-18th century
# 3                                                None               None
# 4                                                None       20th century
# ..                                                ...                ...
# 94                                               None       20th century
# 95                                               None       20th century
# 96                                               None       20th century
# 97                                               None       20th century
# 98                                               None       20th century
#
#     Object_ID Accession_Method                   Period    Rank Edition  \
# 0      240212             Gift                     None  247828    None
# 1      245755             Gift                     None  253391    None
# 2      247933             Gift                     None  248777    None
# 3      202700         Purchase  Qing dynasty, 1644-1911   90034    None
# 4      202986          Bequest                     None   85783    None
# ..        ...              ...                      ...     ...     ...
# 94     127739         Transfer                     None   33381    None
# 95     127747         Transfer                     None   33410    None
# 96     127748         Transfer                     None   33411    None
# 97     129758         Transfer                     None   31587    None
# 98     133408         Transfer                     None   27823    None
#
#      Culture                               Signed Date_Of_Last_Page_View  \
# 0     French                                 None             2019-04-29
# 1    British                                 None             2019-04-08
# 2     German                                 None             2019-08-28
# 3    Chinese                                 None             2020-02-26
# 4   Japanese  signature (illegible) and two seals             2016-02-22
# ..       ...                                  ...                    ...
# 94  American                                 None             2019-10-03
# 95  American                                 None             2019-07-09
# 96  American                                 None             2018-10-02
# 97  American                                 None             2017-10-29
# 98  American                                 None             2015-11-09
#
#    Style                        Technique  Date_End  \
# 0   None                          Etching         0
# 1   None                        Engraving         0
# 2   None                          Etching         0
# 3   None                             None         0
# 4   None                             None         0
# ..   ...                              ...       ...
# 94  None  Negative, gelatin silver (film)      1955
# 95  None  Negative, gelatin silver (film)      1946
# 96  None  Negative, gelatin silver (film)      1946
# 97  None  Negative, gelatin silver (film)      1945
# 98  None  Negative, gelatin silver (film)      1953
#
#    Date_Of_Last_Page_View_String
# 0                     04/29/2019
# 1                     04/08/2019
# 2                     08/28/2019
# 3                     02/26/2020
# 4                     02/22/2016
# ..                           ...
# 94                    10/03/2019
# 95                    07/09/2019
# 96                    10/02/2018
# 97                    10/29/2017
# 98                    11/09/2015
#
# [99 rows x 18 columns]

# %%
# DATA TRANSFORMATION # 2
# The technique ID has an extra .0 at the end which is unnecessary
# First, remove the NAN values in that column
df = df[pd.notnull(df['Technique_ID'])]
df
# Out:
#                                                 Title  Date_Begin  \
# 0                      Cat Playing with a Grass Snake           0
# 1                                             The Cat           0
# 2                                            Wild Cat           0
# 7                             Old Women with Two Cats           0
# 8                              Cat and the Caged Bird           0
# ..                                                ...         ...
# 94  Untitled (two cats in boxing ring wearing gloves)        1945
# 95  Untitled (two standing cats wearing gloves and...        1946
# 96  Untitled (man standing behind small boxing rin...        1946
# 97  Untitled (woman seated with cat on sofa in liv...        1935
# 98  Untitled (wedding guests watching a cat eat fr...        1953
#
#     Total_Page_Views  Technique_ID  \
# 0                 51         116.0
# 1                 12          98.0
# 2                  3         116.0
# 7                  9         116.0
# 8                 14         116.0
# ..               ...           ...
# 94               218         107.0
# 95                30         107.0
# 96                20         107.0
# 97                 5         107.0
# 98                12         107.0
#
#                                            Provenance            Century  \
# 0   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 1   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 2   John Witt Randall, bequest to his sister.\r\nB...  17th-18th century
# 7                                                None       17th century
# 8                                                None       17th century
# ..                                                ...                ...
# 94                                               None       20th century
# 95                                               None       20th century
# 96                                               None       20th century
# 97                                               None       20th century
# 98                                               None       20th century
#
#     Object_ID Accession_Method Period    Rank Edition   Culture Signed  \
# 0      240212             Gift   None  247828    None    French   None
# 1      245755             Gift   None  253391    None   British   None
# 2      247933             Gift   None  248777    None    German   None
# 7      234058             None   None  257129    None    French   None
# 8      234410             None   None  256803    None    French   None
# ..        ...              ...    ...     ...     ...       ...    ...
# 94     127739         Transfer   None   33381    None  American   None
# 95     127747         Transfer   None   33410    None  American   None
# 96     127748         Transfer   None   33411    None  American   None
# 97     129758         Transfer   None   31587    None  American   None
# 98     133408         Transfer   None   27823    None  American   None
#
#    Date_Of_Last_Page_View Style                        Technique  Date_End  \
# 0              2019-04-29  None                          Etching         0
# 1              2019-04-08  None                        Engraving         0
# 2              2019-08-28  None                          Etching         0
# 7              2019-04-08  None                          Etching         0
# 8              2013-10-13  None                          Etching         0
# ..                    ...   ...                              ...       ...
# 94             2019-10-03  None  Negative, gelatin silver (film)      1955
# 95             2019-07-09  None  Negative, gelatin silver (film)      1946
# 96             2018-10-02  None  Negative, gelatin silver (film)      1946
# 97             2017-10-29  None  Negative, gelatin silver (film)      1945
# 98             2015-11-09  None  Negative, gelatin silver (film)      1953
#
#    Date_Of_Last_Page_View_String
# 0                     04/29/2019
# 1                     04/08/2019
# 2                     08/28/2019
# 7                     04/08/2019
# 8                     10/13/2013
# ..                           ...
# 94                    10/03/2019
# 95                    07/09/2019
# 96                    10/02/2018
# 97                    10/29/2017
# 98                    11/09/2015
#
# [80 rows x 18 columns]

# %%
# Next, convert the variable to a string that removes the .0 at the end
df['Technique_ID'] = df['Technique_ID'].astype(str).replace('\.0', '', regex=True)
df
# Out:
# C:\Users\saroj\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 Title  Date_Begin  \
# 0                      Cat Playing with a Grass Snake           0
# 1                                             The Cat           0
# 2                                            Wild Cat           0
# 7                             Old Women with Two Cats           0
# 8                              Cat and the Caged Bird           0
# ..                                                ...         ...
# 94  Untitled (two cats in boxing ring wearing gloves)        1945
# 95  Untitled (two standing cats wearing gloves and...        1946
# 96  Untitled (man standing behind small boxing rin...        1946
# 97  Untitled (woman seated with cat on sofa in liv...        1935
# 98  Untitled (wedding guests watching a cat eat fr...        1953
#
#     Total_Page_Views Technique_ID  \
# 0                 51          116
# 1                 12           98
# 2                  3          116
# 7                  9          116
# 8                 14          116
# ..               ...          ...
# 94               218          107
# 95                30          107
# 96                20          107
# 97                 5          107
# 98                12          107
#
#                                            Provenance            Century  \
# 0   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 1   John Witt Randall, bequest to his sister.\r\nB...       19th century
# 2   John Witt Randall, bequest to his sister.\r\nB...  17th-18th century
# 7                                                None       17th century
# 8                                                None       17th century
# ..                                                ...                ...
# 94                                               None       20th century
# 95                                               None       20th century
# 96                                               None       20th century
# 97                                               None       20th century
# 98                                               None       20th century
#
#     Object_ID Accession_Method Period    Rank Edition   Culture Signed  \
# 0      240212             Gift   None  247828    None    French   None
# 1      245755             Gift   None  253391    None   British   None
# 2      247933             Gift   None  248777    None    German   None
# 7      234058             None   None  257129    None    French   None
# 8      234410             None   None  256803    None    French   None
# ..        ...              ...    ...     ...     ...       ...    ...
# 94     127739         Transfer   None   33381    None  American   None
# 95     127747         Transfer   None   33410    None  American   None
# 96     127748         Transfer   None   33411    None  American   None
# 97     129758         Transfer   None   31587    None  American   None
# 98     133408         Transfer   None   27823    None  American   None
#
#    Date_Of_Last_Page_View Style                        Technique  Date_End  \
# 0              2019-04-29  None                          Etching         0
# 1              2019-04-08  None                        Engraving         0
# 2              2019-08-28  None                          Etching         0
# 7              2019-04-08  None                          Etching         0
# 8              2013-10-13  None                          Etching         0
# ..                    ...   ...                              ...       ...
# 94             2019-10-03  None  Negative, gelatin silver (film)      1955
# 95             2019-07-09  None  Negative, gelatin silver (film)      1946
# 96             2018-10-02  None  Negative, gelatin silver (film)      1946
# 97             2017-10-29  None  Negative, gelatin silver (film)      1945
# 98             2015-11-09  None  Negative, gelatin silver (film)      1953
#
#    Date_Of_Last_Page_View_String
# 0                     04/29/2019
# 1                     04/08/2019
# 2                     08/28/2019
# 7                     04/08/2019
# 8                     10/13/2013
# ..                           ...
# 94                    10/03/2019
# 95                    07/09/2019
# 96                    10/02/2018
# 97                    10/29/2017
# 98                    11/09/2015
#
# [80 rows x 18 columns]

# %%
# Dataframe is now in a usable format
# However, in case it is needed, exporting to CSV
df.to_csv(r'Formatted_dataset.csv')
